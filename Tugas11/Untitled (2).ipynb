# %%
plt.figure(figsize=(25, 10))
plt.title('Dendrogram Hierarchical Klastering')
plt.xlabel('Data')
plt.ylabel('Jarak')
dendrogram(Z)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_2232\678875397.py in <module>
# ----> 1 plt.figure(figsize=(25, 10))
#       2 plt.title('Dendrogram Hierarchical Klastering')
#       3 plt.xlabel('Data')
#       4 plt.ylabel('Jarak')
#       5 dendrogram(Z)
#
# NameError: name 'plt' is not defined

# %%
plt.figure(figsize=(23, 2))
plt.title('Dendrogram Hierarchical Klastering')
plt.xlabel('Data')
plt.ylabel('Jarak')
dendrogram(Z)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_2232\1096362510.py in <module>
# ----> 1 plt.figure(figsize=(23, 2))
#       2 plt.title('Dendrogram Hierarchical Klastering')
#       3 plt.xlabel('Data')
#       4 plt.ylabel('Jarak')
#       5 dendrogram(Z)
#
# NameError: name 'plt' is not defined

# %%
from matplotlib import pyplot as plt
from scipy.cluster.hierarchy import dendrogram, linkage
import numpy as np

# %%
x = np.array([[1,2],[3.5,5.5],[3,3],[5,2.5],[5,3.5]])

# %%
print(x)
# Out:
# [[1.  2. ]
#  [3.5 5.5]
#  [3.  3. ]
#  [5.  2.5]
#  [5.  3.5]]

# %%
from matplotlib import pyplot as plt
from scipy.cluster.hierarchy import dendrogram, linkage
import numpy as np

# %%
x = np.array([[2,1],[4.5,3.5],[2,6],[6,4.5],[7,3.2]])

# %%
print(x)
# Out:
# [[2.  1. ]
#  [4.5 3.5]
#  [2.  6. ]
#  [6.  4.5]
#  [7.  3.2]]

# %%
Z = linkage(x)

# %%
print(Z)
# Out:
# [[3.         4.         1.64012195 2.        ]
#  [1.         5.         1.80277564 3.        ]
#  [0.         6.         3.53553391 4.        ]
#  [2.         7.         3.53553391 5.        ]]

# %%
plt.figure(figsize=(25, 10))
plt.title('Dendrogram Hierarchical Klastering')
plt.xlabel('Data')
plt.ylabel('Jarak')
dendrogram(Z)
plt.show()
