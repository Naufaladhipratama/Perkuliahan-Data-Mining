# %%
import pandas as pd
import numpy as np

# %%
dataset = pd.read_csv("Databus.csv.csv")
dataset
# Out:
#      tahun  bulan                    jenis kode_trayek  \
# 0     2021     12               Mikrotrans      JAK.88
# 1     2021     12               Mikrotrans      JAK.85
# 2     2021     12               Mikrotrans      JAK.84
# 3     2021     12               Mikrotrans      JAK.80
# 4     2021     12               Mikrotrans      JAK.77
# ..     ...    ...                      ...         ...
# 117   2021     12  Angkutan Umum Integrasi          1A
# 118   2021     12  Angkutan Umum Integrasi         12B
# 119   2021     12  Angkutan Umum Integrasi         11Q
# 120   2021     12  Angkutan Umum Integrasi         11D
# 121   2021     12  Angkutan Umum Integrasi         10K
#
#                                    trayek  jumlah_penumpang
# 0    Terminal Tanjung Priok - Ancol Barat             43967
# 1                Bintara - Cipinang Indah             40103
# 2    Terminal Kampung Melayu - Kapin Raya             59193
# 3               Rawa Buaya - Rawa Kompeni             70475
# 4           Tanjung Priok - Jembatan Item             77697
# ..                                    ...               ...
# 117                      PIK - Balai Kota                 0
# 118                         Pluit - Senen                 0
# 119  Kampung Melayu - Pulo Gebang via BKT                 0
# 120   Pulo Gebang - Pulo Gadung 2 via PIK                 0
# 121  Tanjung Priok - Senen via Taman  BMW                 0
#
# [122 rows x 6 columns]

# %%
dataset = pd.read_csv('Databus.csv.csv')
x = dataset.iloc[:, :-1].values
y = dataset.iloc[:, -1].values

# %%
print(x)
# Out:
# [[2021 12 'Mikrotrans' 'JAK.88' 'Terminal Tanjung Priok - Ancol Barat']
#  [2021 12 'Mikrotrans' 'JAK.85' 'Bintara - Cipinang Indah']
#  [2021 12 'Mikrotrans' 'JAK.84' 'Terminal Kampung Melayu - Kapin Raya']
#  [2021 12 'Mikrotrans' 'JAK.80' 'Rawa Buaya - Rawa Kompeni']
#  [2021 12 'Mikrotrans' 'JAK.77' 'Tanjung Priok - Jembatan Item']
#  [2021 12 'Mikrotrans' 'JAK.75' 'Cililitan - Kp. Pulo']
#  [2021 12 'Mikrotrans' 'JAK.74' 'Terminal Rawamangun - Cipinang Muara']
#  [2021 12 'Mikrotrans' 'JAK.73' 'Jambore Cibubur - Pasar Rebo']
#  [2021 12 'Mikrotrans' 'JAK.72'
#   'Kampung Rambutan - Pasar Rebo via Poncol']
#  [2021 12 'Mikrotrans' 'JAK.71' 'Kampung Rambutan - Pinang Ranti']
#  [2021 12 'Mikrotrans' 'JAK.64' 'Lenteng Agung - Aseli']
#  [2021 12 'Mikrotrans' 'JAK.61'
#   'Cempaka Putih - Pulo Gadung via Kelapa Gading']
#  [2021 12 'Mikrotrans' 'JAK.60' 'Kelapa Gading - Rusun Kemayoran']
#  [2021 12 'Mikrotrans' 'JAK.59' 'Rawamangun - Tanah Merah']
#  [2021 12 'Mikrotrans' 'JAK.58' 'Cilingcing - Rorotan']
#  [2021 12 'Mikrotrans' 'JAK.56' 'Grogol - Srengseng']
#  [2021 12 'Mikrotrans' 'JAK.54' 'Grogol - Benhil']
#  [2021 12 'Mikrotrans' 'JAK.53' 'Grogol - Pos Pengumben via Slipi']
#  [2021 12 'Mikrotrans' 'JAK.52' 'Kalideres - Muara Angke']
#  [2021 12 'Mikrotrans' 'JAK.51' 'Taman Kota - Budi Luhur']
#  [2021 12 'Mikrotrans' 'JAK.50' 'Kalideres - Puri Kembangan']
#  [2021 12 'Mikrotrans' 'JAK.49' 'Lebak Bulus - Cipulir']
#  [2021 12 'Mikrotrans' 'JAK.47' 'Pasar Minggu - Ciganjur via KB Ragunan']
#  [2021 12 'Mikrotrans' 'JAK.46' 'Pasar Minggu - Jagakarsa']
#  [2021 12 'Mikrotrans' 'JAK.45' 'Lebak Bulus - Ragunan']
#  [2021 12 'Mikrotrans' 'JAK.44' 'Andara - Stasiun Universitas Pancasila']
#  [2021 12 'Mikrotrans' 'JAK.43' 'Tongtek - Cililitan']
#  [2021 12 'Mikrotrans' 'JAK.42' 'Kampung Melayu - Pondok Kelapa']
#  [2021 12 'Mikrotrans' 'JAK.41' 'Kampung Melayu - Ppulo Gadung']
#  [2021 12 'Mikrotrans' 'JAK.40'
#   'Harapan Baru - Pulo Gebang via Rawa Kuning']
#  [2021 12 'Mikrotrans' 'JAK.39' 'Kalimalang - Duren Sawit']
#  [2021 12 'Mikrotrans' 'JAK.38' 'Bulak Ringin - Kampung Rambutan']
#  [2021 12 'Mikrotrans' 'JAK.37' 'Cililitan - Condet via Kayu Manis']
#  [2021 12 'Mikrotrans' 'JAK.36' 'Cilangkap - Cililitan']
#  [2021 12 'Mikrotrans' 'JAK.35' 'Pangkalan  Jati - Rawamangun']
#  [2021 12 'Mikrotrans' 'JAK.34' 'Rawamangun - Klender']
#  [2021 12 'Mikrotrans' 'JAK.33' 'Pulo Gadung - Kota']
#  [2021 12 'Mikrotrans' 'JAK.32' 'Lebak Bulus - Petukangan']
#  [2021 12 'Mikrotrans' 'JAK.31' 'Blok M - Andara']
#  [2021 12 'Mikrotrans' 'JAK.30' 'Grogol - Meruya via Roxy']
#  [2021 12 'Mikrotrans' 'JAK.29' 'Tanjung Priok - Sukapura']
#  [2021 12 'Mikrotrans' 'JAK.28' 'Kp. Rambutan - Taman Wiladatika']
#  [2021 12 'Mikrotrans' 'JAK.27' 'Pulo Gebang - Rorotan']
#  [2021 12 'Mikrotrans' 'JAK.26' 'Rawamangun - Duren Sawit']
#  [2021 12 'Mikrotrans' 'JAK.25' 'Kp. Rambutan - Kalisari']
#  [2021 12 'Mikrotrans' 'JAK.24' 'Senen - Pulo Gadung via Kelapa Gading']
#  [2021 12 'Mikrotrans' 'JAK.22' 'Dwikora - Penas Kalimalang']
#  [2021 12 'Mikrotrans' 'JAK.21' 'Cililitan - Dwikora']
#  [2021 12 'Mikrotrans' 'JAK.20' 'Cawang UKI - Lubang Buaya']
#  [2021 12 'Mikrotrans' 'JAK,19' 'Pinang Ranti - Kampung Rambutan']
#  [2021 12 'Mikrotrans' 'JAK.18' 'Kalibata - Kuningan']
#  [2021 12 'Mikrotrans' 'JAK.17' 'Senen - Pulo Gadung ']
#  [2021 12 'Mikrotrans' 'JAK.16' 'Cililitan - Condet via Kayu Manis']
#  [2021 12 'Mikrotrans' 'JAK.15' 'Bulak Turi - Tanjung Priok']
#  [2021 12 'Mikrotrans' 'JAK.14' 'Tanah Abang - Meruya']
#  [2021 12 'Mikrotrans' 'JAK.13'
#   'Tanah Abang - Kota Intan via Jembatan Lima']
#  [2021 12 'Mikrotrans' 'JAK.12'
#   'Tanah Abang - Kebayoran Lama via Pos Pengumben']
#  [2021 12 'Mikrotrans' 'JAK.117' 'Tanjung Priok - Tanah Merdeka']
#  [2021 12 'Mikrotrans' 'JAK.112' 'Terminal Tanah Merah - Pulo Gadung']
#  [2021 12 'Mikrotrans' 'JAK.11' 'Tanah Abang - Kebayoran Lama ']
#  [2021 12 'Mikrotrans' 'JAK.10B' nan]
#  [2021 12 'Mikrotrans' 'JAK.10A' nan]
#  [2021 12 'Mikrotrans' 'JAK.10' 'Tanah Abang - Kota ']
#  [2021 12 'Mikrotrans' 'JAK.09' 'Roxy Mas - Karet']
#  [2021 12 'Mikrotrans' 'JAK.08' 'Roxy - Benhil']
#  [2021 12 'Mikrotrans' 'JAK.07' 'Tanah Abang - Grogol via Tawakal']
#  [2021 12 'Mikrotrans' 'JAK.06' 'Kampung Rambutan - Pondok Gede']
#  [2021 12 'Mikrotrans' 'JAK.05' 'Semper - Rorotan']
#  [2021 12 'Mikrotrans' 'JAK.04' 'Grogol - Tubagus Angke']
#  [2021 12 'Mikrotrans' 'JAK.03' 'Lebak Bulus - Andara']
#  [2021 12 'Mikrotrans' 'JAK.02' 'Kampung Melayu - Duren Sawit']
#  [2021 12 'Mikrotrans' 'JAK.01' 'Tanjung Priok - Plumpang']
#  [2021 12 'BRT' '9' 'Pinang Ranti - Pluit']
#  [2021 12 'BRT' '8' 'Lebak Bulus - Harmoni']
#  [2021 12 'BRT' '7' 'Kampung Rambutan - Kampung Melayu']
#  [2021 12 'BRT' '6' 'Ragunan - Dukuh Atas 2']
#  [2021 12 'BRT' '5' 'Kampung Melayu - Ancol']
#  [2021 12 'BRT' '4' 'Pulo Gadung 2 - Tosari']
#  [2021 12 'BRT' '3' 'Kalideres - Pasar Baru']
#  [2021 12 'BRT' '2' 'Pulo Gadung 1 - Harmoni']
#  [2021 12 'BRT' '13' 'Ciledug - Tendean']
#  [2021 12 'BRT' '12' 'Penjaringan - Sunter Bouleverd Barat']
#  [2021 12 'BRT' '11' 'Pulo Gebang - Kampung Melayu']
#  [2021 12 'BRT' '10' 'Tanjung Priok - PGC 2']
#  [2021 12 'BRT' '1' 'Blok M - Kota']
#  [2021 12 'Angkutan Umum Integrasi' '9H' 'Cipedak - Blok M']
#  [2021 12 'Angkutan Umum Integrasi' '9E' 'Kebayoran Lama - Jelambar']
#  [2021 12 'Angkutan Umum Integrasi' '9D' 'Pasar Minggu - Tanah Abang']
#  [2021 12 'Angkutan Umum Integrasi' '8K' 'Batu Sari-Tanah Abang']
#  [2021 12 'Angkutan Umum Integrasi' '8E' 'Bintaro - Blok M']
#  [2021 12 'Angkutan Umum Integrasi' '8D' 'Joglo - Blok M']
#  [2021 12 'Angkutan Umum Integrasi' '8C' 'Kebayoran Lama - Tanah Abang']
#  [2021 12 'Angkutan Umum Integrasi' '7P' 'Pondok Kelapa - BKN']
#  [2021 12 'Angkutan Umum Integrasi' '7D' 'Pancoran - TMII']
#  [2021 12 'Angkutan Umum Integrasi' '7B' 'Kampung Rambutan - Blok M']
#  [2021 12 'Angkutan Umum Integrasi' '7A' 'Kampung Rambutan - Lebak Bulus']
#  [2021 12 'Angkutan Umum Integrasi' '6R' 'Ragunan - Stasin MRT Fatmawati']
#  [2021 12 'Angkutan Umum Integrasi' '6N' 'Ragunan - Blok M via Kemang']
#  [2021 12 'Angkutan Umum Integrasi' '6M' 'Stasiun Manggarai - Blok  M']
#  [2021 12 'Angkutan Umum Integrasi' '6H' 'Senen - Lebak Bulus']
#  [2021 12 'Angkutan Umum Integrasi' '6C'
#   'Stasin Tebet - Karet via Patra Kuningan']
#  [2021 12 'Angkutan Umum Integrasi' '5M'
#   'Kampung Melayu - Tanah Abang via Cikini']
#  [2021 12 'Angkutan Umum Integrasi' '5F' 'Kampung Melayu - Tanah Abang']
#  [2021 12 'Angkutan Umum Integrasi' '5B' 'Stasiun Tebet - Bidara Cina']
#  [2021 12 'Angkutan Umum Integrasi' '4F' 'Pinang Ranti - Pulo Gadung']
#  [2021 12 'Angkutan Umum Integrasi' '4B' 'Stasiun Manggarai - UI']
#  [2021 12 'Angkutan Umum Integrasi' '3E'
#   'Sentraland Cengkareng - Puri Kembangan']
#  [2021 12 'Angkutan Umum Integrasi' '1R' 'Senen - Tanah Abang']
#  [2021 12 'Angkutan Umum Integrasi' '1Q' 'Rempoa - Blok M']
#  [2021 12 'Angkutan Umum Integrasi' '1P' 'Senen - Bundaran Senayan']
#  [2021 12 'Angkutan Umum Integrasi' '1N' 'Tanah Abang - Blok M']
#  [2021 12 'Angkutan Umum Integrasi' '1M' 'Meruya - Blok M']
#  [2021 12 'Angkutan Umum Integrasi' '1H'
#   'Tanah Abang - Stasiun Gondangdia']
#  [2021 12 'Angkutan Umum Integrasi' '1F'
#   'Stasiun Palmerah - Bundaran Senayan']
#  [2021 12 'Angkutan Umum Integrasi' '1E' 'Pondok  Labu - Blok M']
#  [2021 12 'Angkutan Umum Integrasi' '1C' 'Pesanggrahan - Blok M']
#  [2021 12 'Angkutan Umum Integrasi' '1B' 'Stasiun Palmerah - Tosari']
#  [2021 12 'Angkutan Umum Integrasi' '1A' 'PIK - Balai Kota']
#  [2021 12 'Angkutan Umum Integrasi' '12B' 'Pluit - Senen']
#  [2021 12 'Angkutan Umum Integrasi' '11Q'
#   'Kampung Melayu - Pulo Gebang via BKT']
#  [2021 12 'Angkutan Umum Integrasi' '11D'
#   'Pulo Gebang - Pulo Gadung 2 via PIK']
#  [2021 12 'Angkutan Umum Integrasi' '10K'
#   'Tanjung Priok - Senen via Taman  BMW']]

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x,y,test_size=0.2,random_state=0)

# %%
print(x_train)
# Out:
# [[2021 12 'Angkutan Umum Integrasi' '1H'
#   'Tanah Abang - Stasiun Gondangdia']
#  [2021 12 'Mikrotrans' 'JAK.59' 'Rawamangun - Tanah Merah']
#  [2021 12 'BRT' '6' 'Ragunan - Dukuh Atas 2']
#  [2021 12 'BRT' '8' 'Lebak Bulus - Harmoni']
#  [2021 12 'Mikrotrans' 'JAK.43' 'Tongtek - Cililitan']
#  [2021 12 'Mikrotrans' 'JAK.12'
#   'Tanah Abang - Kebayoran Lama via Pos Pengumben']
#  [2021 12 'Mikrotrans' 'JAK.10' 'Tanah Abang - Kota ']
#  [2021 12 'Mikrotrans' 'JAK.11' 'Tanah Abang - Kebayoran Lama ']
#  [2021 12 'Mikrotrans' 'JAK.26' 'Rawamangun - Duren Sawit']
#  [2021 12 'Mikrotrans' 'JAK.17' 'Senen - Pulo Gadung ']
#  [2021 12 'Mikrotrans' 'JAK.80' 'Rawa Buaya - Rawa Kompeni']
#  [2021 12 'Angkutan Umum Integrasi' '9H' 'Cipedak - Blok M']
#  [2021 12 'Mikrotrans' 'JAK.74' 'Terminal Rawamangun - Cipinang Muara']
#  [2021 12 'Angkutan Umum Integrasi' '4B' 'Stasiun Manggarai - UI']
#  [2021 12 'Mikrotrans' 'JAK.20' 'Cawang UKI - Lubang Buaya']
#  [2021 12 'Angkutan Umum Integrasi' '7P' 'Pondok Kelapa - BKN']
#  [2021 12 'Angkutan Umum Integrasi' '3E'
#   'Sentraland Cengkareng - Puri Kembangan']
#  [2021 12 'Mikrotrans' 'JAK.18' 'Kalibata - Kuningan']
#  [2021 12 'Angkutan Umum Integrasi' '6M' 'Stasiun Manggarai - Blok  M']
#  [2021 12 'Angkutan Umum Integrasi' '1B' 'Stasiun Palmerah - Tosari']
#  [2021 12 'Mikrotrans' 'JAK.42' 'Kampung Melayu - Pondok Kelapa']
#  [2021 12 'Mikrotrans' 'JAK.52' 'Kalideres - Muara Angke']
#  [2021 12 'Angkutan Umum Integrasi' '6C'
#   'Stasin Tebet - Karet via Patra Kuningan']
#  [2021 12 'Mikrotrans' 'JAK.61'
#   'Cempaka Putih - Pulo Gadung via Kelapa Gading']
#  [2021 12 'Mikrotrans' 'JAK.09' 'Roxy Mas - Karet']
#  [2021 12 'Angkutan Umum Integrasi' '7B' 'Kampung Rambutan - Blok M']
#  [2021 12 'BRT' '5' 'Kampung Melayu - Ancol']
#  [2021 12 'Angkutan Umum Integrasi' '8C' 'Kebayoran Lama - Tanah Abang']
#  [2021 12 'Mikrotrans' 'JAK.14' 'Tanah Abang - Meruya']
#  [2021 12 'Mikrotrans' 'JAK.85' 'Bintara - Cipinang Indah']
#  [2021 12 'BRT' '7' 'Kampung Rambutan - Kampung Melayu']
#  [2021 12 'Mikrotrans' 'JAK.27' 'Pulo Gebang - Rorotan']
#  [2021 12 'Mikrotrans' 'JAK.28' 'Kp. Rambutan - Taman Wiladatika']
#  [2021 12 'Mikrotrans' 'JAK.77' 'Tanjung Priok - Jembatan Item']
#  [2021 12 'Mikrotrans' 'JAK.56' 'Grogol - Srengseng']
#  [2021 12 'Mikrotrans' 'JAK.53' 'Grogol - Pos Pengumben via Slipi']
#  [2021 12 'Mikrotrans' 'JAK.16' 'Cililitan - Condet via Kayu Manis']
#  [2021 12 'Mikrotrans' 'JAK.29' 'Tanjung Priok - Sukapura']
#  [2021 12 'Mikrotrans' 'JAK.31' 'Blok M - Andara']
#  [2021 12 'Mikrotrans' 'JAK.75' 'Cililitan - Kp. Pulo']
#  [2021 12 'Mikrotrans' 'JAK.15' 'Bulak Turi - Tanjung Priok']
#  [2021 12 'Angkutan Umum Integrasi' '1M' 'Meruya - Blok M']
#  [2021 12 'Mikrotrans' 'JAK.04' 'Grogol - Tubagus Angke']
#  [2021 12 'Mikrotrans' 'JAK.88' 'Terminal Tanjung Priok - Ancol Barat']
#  [2021 12 'Mikrotrans' 'JAK.35' 'Pangkalan  Jati - Rawamangun']
#  [2021 12 'Mikrotrans' 'JAK.41' 'Kampung Melayu - Ppulo Gadung']
#  [2021 12 'Mikrotrans' 'JAK.13'
#   'Tanah Abang - Kota Intan via Jembatan Lima']
#  [2021 12 'Mikrotrans' 'JAK.34' 'Rawamangun - Klender']
#  [2021 12 'Mikrotrans' 'JAK.46' 'Pasar Minggu - Jagakarsa']
#  [2021 12 'Mikrotrans' 'JAK.38' 'Bulak Ringin - Kampung Rambutan']
#  [2021 12 'Angkutan Umum Integrasi' '8E' 'Bintaro - Blok M']
#  [2021 12 'Mikrotrans' 'JAK.117' 'Tanjung Priok - Tanah Merdeka']
#  [2021 12 'Angkutan Umum Integrasi' '7D' 'Pancoran - TMII']
#  [2021 12 'Angkutan Umum Integrasi' '4F' 'Pinang Ranti - Pulo Gadung']
#  [2021 12 'Mikrotrans' 'JAK.37' 'Cililitan - Condet via Kayu Manis']
#  [2021 12 'Angkutan Umum Integrasi' '1C' 'Pesanggrahan - Blok M']
#  [2021 12 'Mikrotrans' 'JAK.58' 'Cilingcing - Rorotan']
#  [2021 12 'Angkutan Umum Integrasi' '1F'
#   'Stasiun Palmerah - Bundaran Senayan']
#  [2021 12 'Mikrotrans' 'JAK.51' 'Taman Kota - Budi Luhur']
#  [2021 12 'Mikrotrans' 'JAK.40'
#   'Harapan Baru - Pulo Gebang via Rawa Kuning']
#  [2021 12 'Mikrotrans' 'JAK,19' 'Pinang Ranti - Kampung Rambutan']
#  [2021 12 'BRT' '11' 'Pulo Gebang - Kampung Melayu']
#  [2021 12 'Angkutan Umum Integrasi' '12B' 'Pluit - Senen']
#  [2021 12 'Angkutan Umum Integrasi' '11D'
#   'Pulo Gebang - Pulo Gadung 2 via PIK']
#  [2021 12 'BRT' '2' 'Pulo Gadung 1 - Harmoni']
#  [2021 12 'Mikrotrans' 'JAK.03' 'Lebak Bulus - Andara']
#  [2021 12 'BRT' '13' 'Ciledug - Tendean']
#  [2021 12 'Mikrotrans' 'JAK.50' 'Kalideres - Puri Kembangan']
#  [2021 12 'Angkutan Umum Integrasi' '1E' 'Pondok  Labu - Blok M']
#  [2021 12 'BRT' '9' 'Pinang Ranti - Pluit']
#  [2021 12 'BRT' '4' 'Pulo Gadung 2 - Tosari']
#  [2021 12 'Mikrotrans' 'JAK.44' 'Andara - Stasiun Universitas Pancasila']
#  [2021 12 'Mikrotrans' 'JAK.32' 'Lebak Bulus - Petukangan']
#  [2021 12 'BRT' '12' 'Penjaringan - Sunter Bouleverd Barat']
#  [2021 12 'Angkutan Umum Integrasi' '1R' 'Senen - Tanah Abang']
#  [2021 12 'Mikrotrans' 'JAK.22' 'Dwikora - Penas Kalimalang']
#  [2021 12 'Angkutan Umum Integrasi' '1N' 'Tanah Abang - Blok M']
#  [2021 12 'Mikrotrans' 'JAK.30' 'Grogol - Meruya via Roxy']
#  [2021 12 'Angkutan Umum Integrasi' '5F' 'Kampung Melayu - Tanah Abang']
#  [2021 12 'Mikrotrans' 'JAK.07' 'Tanah Abang - Grogol via Tawakal']
#  [2021 12 'Mikrotrans' 'JAK.112' 'Terminal Tanah Merah - Pulo Gadung']
#  [2021 12 'Mikrotrans' 'JAK.60' 'Kelapa Gading - Rusun Kemayoran']
#  [2021 12 'Angkutan Umum Integrasi' '1Q' 'Rempoa - Blok M']
#  [2021 12 'Angkutan Umum Integrasi' '8K' 'Batu Sari-Tanah Abang']
#  [2021 12 'Mikrotrans' 'JAK.02' 'Kampung Melayu - Duren Sawit']
#  [2021 12 'Angkutan Umum Integrasi' '9D' 'Pasar Minggu - Tanah Abang']
#  [2021 12 'Mikrotrans' 'JAK.33' 'Pulo Gadung - Kota']
#  [2021 12 'Mikrotrans' 'JAK.49' 'Lebak Bulus - Cipulir']
#  [2021 12 'BRT' '10' 'Tanjung Priok - PGC 2']
#  [2021 12 'Mikrotrans' 'JAK.71' 'Kampung Rambutan - Pinang Ranti']
#  [2021 12 'Angkutan Umum Integrasi' '5B' 'Stasiun Tebet - Bidara Cina']
#  [2021 12 'Angkutan Umum Integrasi' '11Q'
#   'Kampung Melayu - Pulo Gebang via BKT']
#  [2021 12 'Mikrotrans' 'JAK.05' 'Semper - Rorotan']
#  [2021 12 'Mikrotrans' 'JAK.08' 'Roxy - Benhil']
#  [2021 12 'Angkutan Umum Integrasi' '1A' 'PIK - Balai Kota']
#  [2021 12 'Mikrotrans' 'JAK.21' 'Cililitan - Dwikora']
#  [2021 12 'Mikrotrans' 'JAK.25' 'Kp. Rambutan - Kalisari']]

# %%
print(x_test)
# Out:
# [[2021 12 'BRT' '1' 'Blok M - Kota']
#  [2021 12 'Angkutan Umum Integrasi' '6N' 'Ragunan - Blok M via Kemang']
#  [2021 12 'Mikrotrans' 'JAK.64' 'Lenteng Agung - Aseli']
#  [2021 12 'Mikrotrans' 'JAK.01' 'Tanjung Priok - Plumpang']
#  [2021 12 'Mikrotrans' 'JAK.72'
#   'Kampung Rambutan - Pasar Rebo via Poncol']
#  [2021 12 'Mikrotrans' 'JAK.24' 'Senen - Pulo Gadung via Kelapa Gading']
#  [2021 12 'Mikrotrans' 'JAK.47' 'Pasar Minggu - Ciganjur via KB Ragunan']
#  [2021 12 'Mikrotrans' 'JAK.73' 'Jambore Cibubur - Pasar Rebo']
#  [2021 12 'Mikrotrans' 'JAK.10A' nan]
#  [2021 12 'Angkutan Umum Integrasi' '8D' 'Joglo - Blok M']
#  [2021 12 'Angkutan Umum Integrasi' '9E' 'Kebayoran Lama - Jelambar']
#  [2021 12 'Angkutan Umum Integrasi' '1P' 'Senen - Bundaran Senayan']
#  [2021 12 'Mikrotrans' 'JAK.36' 'Cilangkap - Cililitan']
#  [2021 12 'Mikrotrans' 'JAK.06' 'Kampung Rambutan - Pondok Gede']
#  [2021 12 'Mikrotrans' 'JAK.84' 'Terminal Kampung Melayu - Kapin Raya']
#  [2021 12 'BRT' '3' 'Kalideres - Pasar Baru']
#  [2021 12 'Angkutan Umum Integrasi' '6H' 'Senen - Lebak Bulus']
#  [2021 12 'Mikrotrans' 'JAK.45' 'Lebak Bulus - Ragunan']
#  [2021 12 'Angkutan Umum Integrasi' '10K'
#   'Tanjung Priok - Senen via Taman  BMW']
#  [2021 12 'Mikrotrans' 'JAK.39' 'Kalimalang - Duren Sawit']
#  [2021 12 'Angkutan Umum Integrasi' '7A' 'Kampung Rambutan - Lebak Bulus']
#  [2021 12 'Angkutan Umum Integrasi' '5M'
#   'Kampung Melayu - Tanah Abang via Cikini']
#  [2021 12 'Mikrotrans' 'JAK.10B' nan]
#  [2021 12 'Mikrotrans' 'JAK.54' 'Grogol - Benhil']
#  [2021 12 'Angkutan Umum Integrasi' '6R' 'Ragunan - Stasin MRT Fatmawati']]

# %%
from sklearn.impute import SimpleImputer
imputer = SimpleImputer(missing_values=np.nan, strategy="mean")
imputer.fit(x[:, 1:3])
x[:, 1:3] = imputer.transform(x[:, 1:3])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_3296\3641345858.py in <module>
#       1 from sklearn.impute import SimpleImputer
#       2 imputer = SimpleImputer(missing_values=np.nan, strategy="mean")
# ----> 3 imputer.fit(x[:, 1:3])
#       4 x[:, 1:3] = imputer.transform(x[:, 1:3])
#
# ~\anaconda3\lib\site-packages\sklearn\impute\_base.py in fit(self, X, y)
#     317             Fitted estimator.
#     318         """
# --> 319         X = self._validate_input(X, in_fit=True)
#     320
#     321         # default fill_value is 0 for numerical input and "missing_value"
#
# ~\anaconda3\lib\site-packages\sklearn\impute\_base.py in _validate_input(self, X, in_fit)
#     283                     )
#     284                 )
# --> 285                 raise new_ve from None
#     286             else:
#     287                 raise ve
#
# ValueError: Cannot use mean strategy with non-numeric data:
# could not convert string to float: 'Mikrotrans'
