# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import sklearn

# %%
dataset = pd.read_excel('ElectricityConsumptionAndProduction.xlsx')
x = dataset.iloc[:, 1].values
y = dataset.iloc[:, 2].values

# %%
dataset.keys()
# Out:
# Index(['DateTime', 'Consumption', 'Production', 'Nuclear', 'Wind',
#        'Hydroelectric', 'Oil and Gas', 'Coal', 'Solar', 'Biomass'],
#       dtype='object')

# %%
dataset.shape
# Out:
# (36772, 10)

# %%
dataku = pd.DataFrame(dataset)
dataku.head()
# Out:
#              DateTime  Consumption  Production  Nuclear  Wind  Hydroelectric  \
# 0 2019-01-01 00:00:00         6352        6527     1395    79           1383
# 1 2019-01-01 01:00:00         6116        5701     1393    96           1112
# 2 2019-01-01 02:00:00         5873        5676     1393   142           1030
# 3 2019-01-01 03:00:00         5682        5603     1397   191            972
# 4 2019-01-01 04:00:00         5557        5454     1393   159            960
#
#    Oil and Gas  Coal  Solar  Biomass
# 0         1896  1744      0       30
# 1         1429  1641      0       30
# 2         1465  1616      0       30
# 3         1455  1558      0       30
# 4         1454  1458      0       30

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.2, random_state=0)

# %%
from sklearn.linear_model import LinearRegression

regressor = LinearRegression()
regressor.fit(x_train.reshape(-1, 1), y_train.reshape(-1, 1))
# Out:
# LinearRegression()

# %%
from sklearn.linear_model import LinearRegression

regressor = LinearRegression()
regressor.fit(x_train.reshape(-1, 1), y_train.reshape(-1, 1))
# Out:
# LinearRegression()

# %%
y_pred = regressor.predict(x_test.reshape(-1, 1))

# %%
plt.scatter(dataku.Consumption, dataku.Production)
plt.xlabel("Konsumsi")
plt.ylabel("Produksi")
plt.title("Grafik Konsumsi vs Produksi")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
plt.figure(figsize=(10, 8))
plt.scatter(x_train.reshape(-1, 1), y_train.reshape(-1, 1), color='blue')
plt.plot(x_train.reshape(-1, 1), regressor.predict(x_train.reshape(-1, 1)), color='red')
plt.title('Konsumsi Terhadap Produksi (Training Set)')
plt.xlabel('Konsumsi')
plt.ylabel('Produksi')
plt.show()

# %%
plt.figure(figsize=(10, 8))
plt.scatter(x_test.reshape(-1, 1), y_test.reshape(-1, 1), color='blue')
plt.plot(x_test.reshape(-1, 1), regressor.predict(x_test.reshape(-1, 1)), color='red')
plt.title('Konsumsi Terhadap Produksi (Test Set)')
plt.xlabel('Konsumsi')
plt.ylabel('Produksi')
plt.show()
